# %% [markdown]
# # Begining of Section: Basic Data Visualisation - Matplotlib and Seaborn

# %%
import numpy as np
import pandas as pd  # To import data as DataFrame. Pandas is built on NumPy so you need that as well.
import matplotlib.pyplot as plt # For plotting

# %%
pwd #Gets the current working directory of your computer
# Out:
# 'C:\\Users\\ioann\\Documents\\diplomatiki'

# %%
df = pd.read_csv('Piece_Dim.csv', index_col='Item_No')

# %%
df.head()
# Out:
#          Length  Width  Height Operator
# Item_No
# Item-1   102.67  49.53   19.69     Op-1
# Item-2   102.50  51.42   19.63     Op-1
# Item-3    95.37  52.25   21.51     Op-1
# Item-4    94.77  49.24   18.60     Op-1
# Item-5   104.26  47.90   19.46     Op-1

# %%
df.describe()
# Out:
#            Length      Width     Height
# count   50.000000  50.000000  50.000000
# mean   100.128800  49.461400  20.014000
# std      5.075593   2.615639   1.074069
# min     89.820000  44.460000  17.370000
# 25%     95.675000  48.105000  19.375000
# 50%     99.830000  49.315000  19.930000
# 75%    104.402500  50.780000  20.595000
# max    110.540000  55.760000  23.110000

# %% [markdown]
# ## Histogram

# %%
plt.hist(df['Length'])  # 10 bins by default
# Out:
# (array([2., 3., 9., 6., 6., 7., 4., 6., 5., 2.]),
#  array([ 89.82 ,  91.892,  93.964,  96.036,  98.108, 100.18 , 102.252,
#         104.324, 106.396, 108.468, 110.54 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Length'], bins=15)
plt.show()

# %%
plt.hist(df['Length'], bins=15, color='Red')              # https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html
plt.xlabel("Length in mm.")
plt.ylabel("Count")
plt.title("Histogram of piece length")
plt.show()

# %% [markdown]
# ## Box and Whisker Plot

# %%
plt.boxplot(df['Length'])
plt.show()

# For more info on 'boxplot' see--  https://matplotlib.org/3.1.1/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py

# %%
op1 = df[df['Operator']=='Op-1']
op2 = df[df['Operator']=='Op-2']

# %%
op2.head()
# Out:
#          Length  Width  Height Operator
# Item_No
# Item-26   95.69  49.48   17.37     Op-2
# Item-27  105.88  49.53   18.70     Op-2
# Item-28  101.68  52.79   19.42     Op-2
# Item-29   93.54  51.05   19.29     Op-2
# Item-30   99.66  48.40   20.64     Op-2

# %%
plt.boxplot([op1['Length'], op2['Length']])
plt.show()

# %%
plt.boxplot([op1['Length'], op2['Length']], notch=True)
plt.xlabel('Operator')
plt.ylabel('Length in mm')
plt.title('Box plot by operator')
plt.show()

# %% [markdown]
# ### Line Plot

# %%
plt.plot(df['Length'])
plt.show()

# %%
plt.plot(df['Length'])
mean_l = df['Length'].mean()
sd_l = df['Length'].std()
plt.axhline(y=mean_l, color='red', linestyle='-')
plt.axhline(y=(mean_l + 3*sd_l), color='red', linestyle='--')
plt.axhline(y=(mean_l - 3*sd_l), color='red', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,3)) # Not covered in the video- To change the figure size
plt.plot(df['Length'])
mean_l = df['Length'].mean()
sd_l = df['Length'].std()
plt.axhline(y=mean_l, color='red', linestyle='-')
plt.axhline(y=(mean_l + 3*sd_l), color='red', linestyle='--')
plt.axhline(y=(mean_l - 3*sd_l), color='red', linestyle='--')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(df['Length'], df['Width'])

# %%
plt.scatter(data=df, x= 'Length', y='Width', marker='v');

# %% [markdown]
# ### Bar Plot

# %%
opers = ['Operator 1', 'Operator 2', 'Operator3']
pieces = [50, 35, 70]
plt.bar(opers, pieces)
plt.show()

# %%
lowl = df[df['Length']<95]['Length'].count()           
medl = df[(df['Length']>=95) & (df['Length']<=105)]['Length'].count()
higl = df[df['Length']>105]['Length'].count()

sizel = [lowl, medl, higl]
groupl = ['< 95', 'Bewteen 95 and 105', '>105']
plt.bar(groupl, sizel)
plt.show()

# %% [markdown]
# ### Saving the Plot

# %%
plt.bar(groupl, sizel)
plt.savefig('MyBoxPlot.jpg')

# %%
plt.bar(groupl, sizel)
plt.savefig('MyBoxPlot300.jpg', dpi=300)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F69C-3472
#
#  Directory of C:\Users\ioann\Documents\diplomatiki
#
# 15/12/2024  02:50 μμ    <DIR>          .
# 17/11/2024  08:33 μμ    <DIR>          ..
# 15/12/2024  02:42 μμ    <DIR>          .ipynb_checkpoints
# 17/09/2024  10:48 μμ           180.719 ARIMA.ipynb
# 09/12/2024  01:33 πμ    <DIR>          bar.parquet
# 09/10/2023  08:55 μμ           191.441 best cnn.ipynb
# 13/11/2022  11:27 πμ           186.489 CarPrice_example.ipynb
# 21/11/2022  11:02 πμ            77.481 CarPrice_example-manualsearch.ipynb
# 24/11/2022  12:51 πμ            57.334 CarPrice_example-single.ipynb
# 16/10/2022  11:49 μμ           198.278 CarPrice_example-test.ipynb
# 03/09/2022  02:46 μμ           104.758 CarPricesData.pkl
# 11/11/2024  01:16 πμ             8.371 Classes and Objects.ipynb
# 15/12/2024  02:50 μμ           219.296 Class-Practices-8.2- Data Visualisation_up.ipynb
# 24/05/2023  12:23 πμ            34.136 cnn 87.ipynb
# 21/05/2023  12:00 πμ            34.465 CNN.ipynb
# 19/04/2023  12:58 μμ            81.320 CNN2.ipynb
# 23/05/2023  11:59 μμ            32.882 CNN-81.ipynb
# 03/11/2024  07:35 μμ            16.384 data.db
# 04/11/2024  01:09 πμ                51 example
# 04/11/2024  01:09 πμ             5.530 Excel_Sample.xlsx
# 09/10/2023  02:13 μμ            22.801 Figure_error.pdf
# 09/10/2023  02:12 μμ            12.687 Figure_loss.pdf
# 09/10/2023  02:13 μμ           469.663 Figure_predicted.pdf
# 09/10/2023  02:13 μμ            43.182 Figure_SNR.pdf
# 16/10/2022  11:49 μμ           125.981 Gaussian-example.ipynb
# 10/12/2024  11:35 πμ           155.355 input_data.csv
# 08/10/2024  10:09 μμ            11.953 lesson1.ipynb
# 08/10/2024  11:55 μμ             7.259 lesson2.ipynb
# 03/11/2024  06:36 μμ         2.091.239 melb_data.csv
# 01/12/2024  12:03 πμ            17.524 MongoDB_Updated.ipynb
# 03/11/2024  06:36 μμ               560 multi_index_example
# 09/11/2024  07:10 μμ                 0 my.db
# 09/11/2024  09:53 μμ             8.192 my_database.db
# 15/12/2024  02:52 μμ            14.441 MyBoxPlot.jpg
# 15/12/2024  02:52 μμ            87.911 MyBoxPlot300.jpg
# 09/12/2024  01:33 πμ            86.212 Pandas_API_on_Spark_up.ipynb
# 25/11/2024  12:16 πμ             1.635 Piece_Dim.csv
# 10/12/2024  12:15 μμ           404.860 power_generation_output.xlsx
# 24/11/2022  01:15 πμ            85.614 proxeiro.ipynb
# 09/12/2024  01:44 πμ            23.770 pyspark_tutorial_install_quickstart_up.ipynb
# 06/12/2023  01:28 πμ           108.531 Resnet 83.67.ipynb
# 18/10/2023  01:03 μμ            27.380 Resnet.ipynb
# 13/11/2022  01:32 πμ           142.618 SNR 2 - 50000.ipynb
# 24/10/2022  01:12 πμ           172.052 SNR.ipynb
# 03/03/2023  12:36 πμ        13.600.889 SNR_BBH-injections-reduced-100k.pkl
# 05/11/2022  08:12 μμ           320.888 SNR_dataset_2_5000.pkl
# 11/11/2022  12:36 μμ         3.200.805 SNR_dataset_2_50000.pkl
# 12/11/2022  11:00 πμ        32.000.809 SNR_dataset_2_500000.pkl
# 23/10/2022  11:40 πμ         1.600.761 SNR_empirical_10000.pkl
# 23/10/2022  11:31 πμ         1.600.790 SNR_empirical_50000.pkl
# 21/11/2022  11:02 πμ            78.081 SNR_real_single.ipynb
# 22/11/2022  01:47 πμ           175.217 SNR_real_single2.ipynb
# 05/02/2023  05:23 μμ            16.314 SNR_real_single-New_reduced-PRELU 2.ipynb
# 31/01/2023  12:57 μμ           285.476 SNR_real_single-New_reduced-PRELU.ipynb
# 23/10/2022  04:44 μμ            17.263 SNR-dataset-NN.ipynb
# 09/11/2024  07:17 μμ    <DIR>          sqlite-python
# 12/11/2024  12:17 πμ           391.595 Tesla_dataset.csv
# 16/10/2022  11:47 μμ                72 Untitled.ipynb
# 17/02/2023  02:11 πμ            22.120 Untitled1.ipynb
# 07/10/2024  01:26 πμ            12.529 Untitled10.ipynb
# 08/10/2024  01:47 μμ             4.679 Untitled11.ipynb
# 13/10/2024  07:14 μμ            13.481 Untitled12.ipynb
# 14/10/2024  12:28 πμ            12.132 Untitled13.ipynb
# 14/10/2024  12:48 πμ             6.667 Untitled14.ipynb
# 14/10/2024  01:42 μμ             5.813 Untitled15.ipynb
# 16/10/2024  12:39 πμ            33.222 Untitled16.ipynb
# 15/10/2024  01:52 μμ            14.767 Untitled17.ipynb
# 15/10/2024  02:41 μμ             6.825 Untitled18.ipynb
# 16/10/2024  09:17 πμ             6.446 Untitled19.ipynb
# 01/03/2023  01:59 μμ           262.155 Untitled2.ipynb
# 16/10/2024  09:30 πμ            11.745 Untitled20.ipynb
# 21/10/2024  12:12 πμ            13.704 Untitled21.ipynb
# 21/10/2024  10:10 πμ             4.753 Untitled22.ipynb
# 22/10/2024  02:10 μμ             4.278 Untitled23.ipynb
# 22/10/2024  10:41 μμ             7.561 Untitled24.ipynb
# 22/10/2024  11:41 μμ             2.791 Untitled25.ipynb
# 22/10/2024  11:53 μμ             6.789 Untitled26.ipynb
# 04/11/2024  07:47 μμ             4.838 Untitled27.ipynb
# 04/11/2024  08:35 μμ            10.727 Untitled28.ipynb
# 09/11/2024  07:17 μμ             4.499 Untitled29.ipynb
# 24/05/2023  10:55 πμ            38.674 Untitled3.ipynb
# 09/11/2024  07:22 μμ             5.793 Untitled30.ipynb
# 09/11/2024  09:56 μμ             8.351 Untitled31.ipynb
# 12/11/2024  12:21 πμ            15.046 Untitled32.ipynb
# 02/12/2024  12:41 πμ            10.962 Untitled33.ipynb
# 09/12/2024  05:27 μμ             7.239 Untitled34.ipynb
# 10/12/2024  12:16 μμ           604.336 Untitled35.ipynb
# 10/12/2024  12:34 μμ             2.434 Untitled36.ipynb
# 21/09/2024  05:55 μμ           122.131 Untitled4.ipynb
# 01/09/2024  06:13 μμ             1.105 Untitled5.ipynb
# 05/03/2023  09:04 μμ             6.572 Untitled6.ipynb
# 03/10/2024  05:51 μμ             5.497 Untitled7.ipynb
# 07/10/2024  01:23 μμ            21.226 Untitled8.ipynb
# 07/10/2024  01:26 πμ            11.073 Untitled9.ipynb
# 25/11/2024  12:16 πμ            72.320 week 8.1 Self-Practice(1).ipynb
# 26/11/2024  03:03 μμ    <DIR>          Week4_Lab_Updated
#               90 File(s)     60.244.595 bytes
#                6 Dir(s)  247.321.800.704 bytes free

# %% [markdown]
# # Section 5 - Visualisation - Using Seaborn

# %% [markdown]
# - Statistical visualisation library based on Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Piece_Dim.csv')

# %%
df.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %% [markdown]
# ## displot() Group of Plots

# %% [markdown]
# ## Histogram

# %%
plt.hist(df['Length']);    #Histogram using Matplotlib (that we learnt earlier)

# %%
sns.histplot(data=df, x='Length', bins=10)
plt.title('Histogram')
plt.show()

# %%
sns.displot(data=df, x='Length');  
#displot (distribution plots)// distplot deprecated 
# It is a combination of histplot, kdeplot, rugplot and ecdfplot. 
# It is defined by kind = hist(default), kde, rug or ecdf

# %%
sns.displot(data=df, x='Length', bins=10);   
#See that it is displot (or histplot) 
# and not distplot (which will be removed in future versions)

# %%
sns.displot(data=df, x='Length', bins=10, hue='Operator'); 
# Does not give a very good picture for the data here

# %%
sns.displot(data=df, x='Length', bins=10, col='Operator')
plt.show()

# %% [markdown]
# ### KDE Plot (Kernel Density Estimate)

# %%
sns.displot(data=df, x='Length', rug=True, color='Red', kind='kde');

# %%
sns.displot(data=df, x='Length', rug=True, color='Red', kind='kde', hue='Operator');

# %%
sns.displot(data=df, x='Length', rug=True, kind='ecdf');

# %%
sns.displot(data=df, x='Length', rug=True, kde=True, kind='hist');

# %% [markdown]
# ### Bivariate Plot

# %%
sns.displot(data=df, x='Length', y='Width');

# %%
sns.displot(data=df, x='Length', y='Width', kind='kde');

# %% [markdown]
# ## catplot() Category  # https://seaborn.pydata.org/tutorial/categorical.html

# %% [markdown]
# Categorical scatterplots:
#
#     stripplot() (with kind="strip"; the default)
#
#     swarmplot() (with kind="swarm")
#
# Categorical distribution plots:
#
#     boxplot() (with kind="box")
#
#     violinplot() (with kind="violin")
#
#     boxenplot() (with kind="boxen")
#
# Categorical estimate plots:
#
#     pointplot() (with kind="point")
#
#     barplot() (with kind="bar")
#
#     countplot() (with kind="count")

# %%
sns.catplot(data=df, x='Operator', y='Length');  #strip plot by default

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='strip');

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='swarm');

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='box');

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='violin');

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='boxen');

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='point');

# %%
sns.catplot(data=df, x='Operator', y='Length', kind='bar');

# %%
sns.catplot(data=df, x='Operator', kind='count');

# %% [markdown]
# ## relplot()

# %% [markdown]
# scatterplot() (with kind="scatter"; the default)
# lineplot() (with kind="line")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Piece_Dim.csv')

# %%
df.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %%
sns.relplot(data=df, x='Length', y='Width');  #The default kind is scatter

# %%
sns.relplot(data=df, x='Length', y='Width', hue='Operator');

# %%
sns.relplot(data=df, x='Length', y='Width', col='Operator');

# %%
sns.relplot(data=df, x='Item_No', y='Length', kind='line', height = 4, aspect=3)
plt.xticks(rotation=45);

# %%
sns.regplot(data=df, x='Length', y='Width')
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Width'>

# %% [markdown]
# ## Visualising Titanic Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()   #Available datasets with Seaborn. You need internet connection to use these.
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.displot(data=titanic, x='age');

# %%
sns.displot(data=titanic, x='age', hue='sex');

# %%
sns.displot(data=titanic, x='age', col='sex');

# %%
sns.displot(data=titanic, x='age', col='sex', hue='survived'); # Does not give a clear picture

# %%
sns.displot(data=titanic, x='age', col='sex', row='survived');

# %%
sns.displot(data=titanic, x='age', col='sex', row='survived', kind='kde');

# %% [markdown]
# ### catplot()

# %%
sns.catplot(data=titanic, x= 'survived', y='age'); # stripplot by default

# %%
sns.catplot(data=titanic, x= 'survived', y='age', kind='swarm', aspect=2); 
#aspect =2 to make it wide

# %%
sns.catplot(data=titanic, x= 'survived', y='age', kind='violin');

# %%
sns.catplot(data=titanic, x= 'survived', y='age', kind='box');

# %%
sns.catplot(data=titanic, x= 'survived', y='age', kind='boxen');

# %%
sns.catplot(data=titanic, x='sex', kind='count');

# %%
sns.catplot(data=titanic, x='sex', kind='count', hue='survived');

# %%
sns.catplot(data=titanic, x='deck', kind='count', hue='survived');

# %% [markdown]
# Home work pratice:
# 1. https://seaborn.pydata.org/introduction.html
# 2. View seaborn example gallery and select 2 which you haven't seen in the practice yet to test (https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# ### End of Section
